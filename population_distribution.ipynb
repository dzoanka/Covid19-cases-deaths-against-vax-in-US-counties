# %% [markdown]
# This notebook presents the distribution of population across US counties and also generates easily readable table with most important data about counties: countyFIPS, Population

# %%
#Imports
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('deaths_pop.csv')

# %%
print('Minimum population: ', df['Population'].min())
print('Minimum population: ', df['Population'].max())
# Out:
# Minimum population:  86
# Minimum population:  10039107

# %%
sns.displot(df, x="Population")

# %%
df_smaller_2mln =  df[ df['Population'] < 2000000]

# %%
sns.histplot(df_smaller_pop, x="Population")
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Count'>

# %%
df_smaller_1mln =  df[ df['Population'] < 1000000]

# %%
sns.histplot(df_smaller_1mln, x="Population")
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Count'>

# %%
df_smaller_500k =  df[ df['Population'] < 500000]

# %%
sns.histplot(df_smaller_500k, x="Population")
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Count'>

# %%
df_smaller_200k =  df[ df['Population'] < 200000]

# %%
g = sns.histplot(df_smaller_200k, x="Population")
xlabels = ['{:,.0f}'.format(x) + 'k' for x in g.get_xticks()/1000]
g.set_xticklabels(xlabels)
# Out:
# <ipython-input-89-9714119887d1>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(xlabels)
# [Text(-25000.0, 0, '-25k'),
#  Text(0.0, 0, '0k'),
#  Text(25000.0, 0, '25k'),
#  Text(50000.0, 0, '50k'),
#  Text(75000.0, 0, '75k'),
#  Text(100000.0, 0, '100k'),
#  Text(125000.0, 0, '125k'),
#  Text(150000.0, 0, '150k'),
#  Text(175000.0, 0, '175k'),
#  Text(200000.0, 0, '200k'),
#  Text(225000.0, 0, '225k')]

# %%
df
# Out:
#       countyFIPS         County Name State  Population  Deaths_begin  \
# 0           1001     Autauga County     AL       55869           160
# 1           1003     Baldwin County     AL      223234           593
# 2           1005     Barbour County     AL       24686            81
# 3           1007        Bibb County     AL       22394            95
# 4           1009      Blount County     AL       57826           198
# ...          ...                 ...   ...         ...           ...
# 3137       56037  Sweetwater County     WY       42343           107
# 3138       56039       Teton County     WY       23464            14
# 3139       56041       Uinta County     WY       20226            31
# 3140       56043    Washakie County     WY        7805            37
# 3141       56045      Weston County     WY        6927            14
#
#       Deaths_end
# 0            163
# 1            608
# 2             83
# 3             95
# 4            204
# ...          ...
# 3137         115
# 3138          15
# 3139          34
# 3140          41
# 3141          16
#
# [3142 rows x 6 columns]
